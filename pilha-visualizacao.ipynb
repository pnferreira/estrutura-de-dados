# %% [markdown]
# # Pilhas
#
# ## Operações

# %% [markdown]
# ![Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.09.48.png](attachment:Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.09.48.png)

# %% [markdown]
# ![Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.08.32.png](attachment:Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.08.32.png)

# %% [markdown]
# ![Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.10.24.png](attachment:Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.10.24.png)

# %% [markdown]
# ![Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.10.32.png](attachment:Captura%20de%20Tela%202023-08-07%20a%CC%80s%2015.10.32.png)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

class Pilha:
    def __init__(self):
        self.pilha = []

    def push(self, elemento):
        self.pilha.append(elemento)

    def pop(self):
        if self.is_empty():
            print("Erro: Pilha está vazia")
        else:
            elemento = self.pilha.pop()
            return elemento

    def top(self):
        if self.is_empty():
            print("Erro: Pilha está vazia")
        else:
            return self.pilha[-1]
    
    def is_empty(self):
        return len(self.pilha) <= 0

    def plot_pilha(self):
        plt.clf()  # Limpa a figura antes de desenhar a nova pilha.
        fig, ax = plt.subplots()
        ax.set_xlim([0, 1])  # Define o limite do eixo x.
        ax.set_ylim([0, max(10, len(self.pilha))])  # Define o limite do eixo y.
        ax.axis('off')  # Remove os eixos.
        height = 1  # Define a altura fixa.
        
        # Adiciona cada retângulo (elemento da pilha) ao gráfico.
        for i, item in enumerate(self.pilha):
            color = 'lightblue' if i != len(self.pilha) - 1 else 'lightcoral'
            rect = patches.Rectangle((0.25, i), 0.5, height, linewidth=1, edgecolor='black', facecolor=color)
            ax.add_patch(rect)
            plt.text(0.5, i + 0.5, item, ha='center', va='center', fontsize=10)
        
        plt.show()

pilha = Pilha()

# %%
pilha.push("elemento 5")

# %%
pilha.pop()
# Out:
# 'elemento 5'

# %%
pilha.plot_pilha()

# %% [markdown]
# Github: https://github.com/pnferreira
